# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL\Desktop\valid_india.csv")
#importing the previous valid address file
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9208\2550714568.py:1: DtypeWarning: Columns (11,26,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\DELL\Desktop\valid_india.csv")

# %%
pd.set_option("display.max_columns", 1000)

# %%
df.reset_index()
# Out:
#        index  Unnamed: 0  Order Number  Run Code  Student ID  \
# 0          0           0        873194         1   113575746
# 1          1           2        873194         1   130668923
# 2          2           3        873194         1   130161337
# 3          3           4        873194         1   130410087
# 4          4           5        873194         1   130146973
# ...      ...         ...           ...       ...         ...
# 20546  20546       20629        873194         1   130271510
# 20547  20547       20646        873194         1   130678092
# 20548  20548       20651        873194         1   127874975
# 20549  20549       20653        873194         1   129791863
# 20550  20550       20660        873194         1   131060573
#
#       Student’s Last Name Student’s First Name Student's Preferred Name  \
# 0                     NaN              Tanisha                      NaN
# 1                       A               Advika                   Advika
# ...

# %%
x=df["ZIP/Postal Code"]

# %%
df["ZIP/Postal Code"].astype(str)
# Out:
# 0        143001
# 1        600023
# 2        606751
# 3        600017
# 4        678684
#           ...
# 20546    226005
# 20547    431605
# 20548    335040
# 20549    560050
# 20550    243002
# Name: ZIP/Postal Code, Length: 20551, dtype: object

# %%
y=df.loc[df['ZIP/Postal Code'].str.len() != 6]

# %%
y
#invalid
# Out:
#        Unnamed: 0  Order Number  Run Code  Student ID Student’s Last Name  \
# 56             58        873194         1   130115344             Abraham
# 154           170        873194         1   130891535             Agarwal
# 162           178        873194         1   129655929             Agarwal
# 255           283        873194         1   130010889             Agarwal
# 318           351        873194         1   128205958             Agarwal
# ...           ...           ...       ...         ...                 ...
# 19017       20564        873194         1   130548300           Yanamadni
# 19035       20584        873194         1   130679339            Yatagiri
# 19041       20590        873194         1   122718107  Yeduguri Sandhinti
# 19068       20618        873194         1   125017259              Yosuva
# 19093       20645        873194         1   124896580             Zarikar
#
#       Student’s First Name Student's Preferred Name Student’s Middle Initial  \
# ...

# %%
v=df[df['ZIP/Postal Code'].str.len() != 6].index
df.drop(v,inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#        Unnamed: 0  Order Number  Run Code  Student ID Student’s Last Name  \
# 0               0        873194         1   113575746                 NaN
# 1               2        873194         1   130668923                   A
# 2               3        873194         1   130161337                   A
# 3               4        873194         1   130410087                   A
# 4               5        873194         1   130146973                   A
# ...           ...           ...       ...         ...                 ...
# 20283       20629        873194         1   130271510               Zahra
# 20284       20646        873194         1   130678092             Zarikar
# 20285       20651        873194         1   127874975                Zehr
# 20286       20653        873194         1   129791863               Zehra
# 20287       20660        873194         1   131060573              Zubair
#
#       Student’s First Name Student's Preferred Name Student’s Middle Initial  \
# ...

# %%
df.head(50)
# Out:
#     Unnamed: 0  Order Number  Run Code  Student ID Student’s Last Name  \
# 0            0        873194         1   113575746                 NaN
# 1            2        873194         1   130668923                   A
# 2            3        873194         1   130161337                   A
# 3            4        873194         1   130410087                   A
# 4            5        873194         1   130146973                   A
# 5            6        873194         1   130146928                   A
# 6            7        873194         1   129197678                   A
# 7            8        873194         1   131061081                   A
# 8            9        873194         1   130422770                   A
# 9           10        873194         1   130278680                   A
# 10          11        873194         1   128745936                   A
# 11          12        873194         1   129490195                   A
# ...

# %%
df.tail(50)
# Out:
#        Unnamed: 0  Order Number  Run Code  Student ID Student’s Last Name  \
# 20238       19835        873194         1   130229548              Vasoya
# 20239       19851        873194         1   130012856             Vatnani
# 20240       19863        873194         1   127450792               Vatsa
# 20241       19878        873194         1   115632723              Vedula
# 20242       19888        873194         1   130125427         Veerapaneni
# 20243       19912        873194         1   127161029          Vemavarapu
# 20244       19932        873194         1   129812958             Venkata
# 20245       19951        873194         1   123761829          Venkatesan
# 20246       19963        873194         1   128992777       Venkateswarar
# 20247       20025        873194         1   124843906               Verma
# 20248       20035        873194         1   129120743               Verma
# 20249       20040        873194         1   124865644               Verma
# ...

# %%
df["Street Address Line 1"].astype(str)
# Out:
# 0                137 St-11 New Pawan Nagar
# 1        C 75 Sunnyvale Apartments 351 352
# 2                    Mettukarkonam Village
# 3                          26 Dr Nair Road
# 4                            Plachikulambu
#                        ...
# 20283                            337/475/1
# 20284                               Nanded
# 20285                      11224 Rupert Rd
# 20286                                India
# 20287                     Sailani Old City
# Name: Street Address Line 1, Length: 20288, dtype: object

# %%
df["Value"]=df["Street Address Line 1"].str.isalpha()

# %%
df
# Out:
#        Unnamed: 0  Order Number  Run Code  Student ID Student’s Last Name  \
# 0               0        873194         1   113575746                 NaN
# 1               2        873194         1   130668923                   A
# 2               3        873194         1   130161337                   A
# 3               4        873194         1   130410087                   A
# 4               5        873194         1   130146973                   A
# ...           ...           ...       ...         ...                 ...
# 20283       20629        873194         1   130271510               Zahra
# 20284       20646        873194         1   130678092             Zarikar
# 20285       20651        873194         1   127874975                Zehr
# 20286       20653        873194         1   129791863               Zehra
# 20287       20660        873194         1   131060573              Zubair
#
#       Student’s First Name Student's Preferred Name Student’s Middle Initial  \
# ...

# %%
inval=df.loc[df["Value"]==True]
#invalid

# %%
val=df.loc[df["Value"]==False]

# %%
val
# Out:
#        Unnamed: 0  Order Number  Run Code  Student ID Student’s Last Name  \
# 0               0        873194         1   113575746                 NaN
# 1               2        873194         1   130668923                   A
# 2               3        873194         1   130161337                   A
# 3               4        873194         1   130410087                   A
# 5               6        873194         1   130146928                   A
# ...           ...           ...       ...         ...                 ...
# 20280       20569        873194         1   127645845               Yardi
# 20282       20619        873194         1   128910769              Yousuf
# 20283       20629        873194         1   130271510               Zahra
# 20285       20651        873194         1   127874975                Zehr
# 20287       20660        873194         1   131060573              Zubair
#
#       Student’s First Name Student's Preferred Name Student’s Middle Initial  \
# ...

# %%
final_valid=val.drop(columns="Value")

# %%
final_valid
#final valid
# Out:
#        Unnamed: 0  Order Number  Run Code  Student ID Student’s Last Name  \
# 0               0        873194         1   113575746                 NaN
# 1               2        873194         1   130668923                   A
# 2               3        873194         1   130161337                   A
# 3               4        873194         1   130410087                   A
# 5               6        873194         1   130146928                   A
# ...           ...           ...       ...         ...                 ...
# 20280       20569        873194         1   127645845               Yardi
# 20282       20619        873194         1   128910769              Yousuf
# 20283       20629        873194         1   130271510               Zahra
# 20285       20651        873194         1   127874975                Zehr
# 20287       20660        873194         1   131060573              Zubair
#
#       Student’s First Name Student's Preferred Name Student’s Middle Initial  \
# ...

# %%
final_valid.to_csv("Final_Valid_Address")

# %%
dt=pd.read_csv(r"C:\Users\DELL\Desktop\invalid_india.csv")

# %%
dt
# Out:
#      Unnamed: 0  Order Number  Run Code  Student ID    Student’s Last Name  \
# 0          1829        873194         1   124289649                 Bansal
# 1          4529        873194         1   128532428                  Dubay
# 2          4692        873194         1   128067126  Enrique Valdes Carter
# 3          7867        873194         1   123510781           Kamalakannan
# 4          9592        873194         1   114240343             Kumarasamy
# ..          ...           ...       ...         ...                    ...
# 110       19692        873194         1   113493820               Vaishnav
# 111       19829        873194         1   127706396                Vashist
# 112       19917        873194         1   105016093                 Vemuri
# 113       19929        873194         1   129272486                 Venkat
# 114       20044        873194         1   130685026                  Verma
#
# ...

# %%
x=dt.append(y)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9208\4049046110.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x=dt.append(y)

# %%
x
# Out:
#        Unnamed: 0  Order Number  Run Code  Student ID    Student’s Last Name  \
# 0            1829        873194         1   124289649                 Bansal
# 1            4529        873194         1   128532428                  Dubay
# 2            4692        873194         1   128067126  Enrique Valdes Carter
# 3            7867        873194         1   123510781           Kamalakannan
# 4            9592        873194         1   114240343             Kumarasamy
# ...           ...           ...       ...         ...                    ...
# 19017       20564        873194         1   130548300              Yanamadni
# 19035       20584        873194         1   130679339               Yatagiri
# 19041       20590        873194         1   122718107     Yeduguri Sandhinti
# 19068       20618        873194         1   125017259                 Yosuva
# 19093       20645        873194         1   124896580                Zarikar
#
# ...

# %%
final_invalid=x.append(inval)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9208\2193131350.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_invalid=x.append(inval)

# %%
final_invalid.to_csv("Final_Invalid_Address")
